# %% [markdown]
# # Linear Regresion scikitlearn

# %% [markdown]
# The objective of this project is to predict wine quality taking into account its components.

# %% [markdown]
# ###### Import pandas and read data base

# %%
import pandas as pd
wine = pd.read_csv("C:\\Users\\DEAM\\Downloads\\winequality-white.csv", sep=';')
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  ...    pH  sulphates  alcohol  quality
# 0               7.0              0.27         0.36            20.7  ...  3.00       0.45      8.8        6
# 1               6.3              0.30         0.34             1.6  ...  3.30       0.49      9.5        6
# 2               8.1              0.28         0.40             6.9  ...  3.26       0.44     10.1        6
# 3               7.2              0.23         0.32             8.5  ...  3.19       0.40      9.9        6
# 4               7.2              0.23         0.32             8.5  ...  3.19       0.40      9.9        6
# ...             ...               ...          ...             ...  ...   ...        ...      ...      ...
# 4893            6.2              0.21         0.29             1.6  ...  3.27       0.50     11.2        6
# 4894            6.6              0.32         0.36             8.0  ...  3.15       0.46      9.6        5
# ...

# %% [markdown]
# Division of the data as all data comes from de same dataframe

# %%
components = list(wine.columns)
components.remove('quality')

x = wine[components]
y = wine['quality']

# %% [markdown]
# Import scikitlearn libraries

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y)

# %% [markdown]
# creating the model

# %%
model = LinearRegression()
model.fit(x_train, y_train)

training_pred = model.predict(x_train)
test_pred = model.predict(x_test)

print('Training R2 is: ', model.score(x_train, y_train))
print('Test R2 is: ', model.score(x_test, y_test))
# Out:
# Training R2 is:  0.282776758054866
# Test R2 is:  0.2754601194276364
